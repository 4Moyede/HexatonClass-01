# %% [markdown]
# # 1. 변수와 연산자
#
# ## 변수
#
# ### 필요한 연산 값의 저장
#
# ![compute](img/compute.png)
#
# Computer란, 계산하는 기계이다. 그 계산의 결과가 지금 우리가 하고있는 Zoom, 게임, 혹은 카카오톡인 것이다.
# 연산을 진행하면서 중간에 발생한 어떤 값이 **다음 연산에 필요한 경우에 따로 저장해서 사용**하는 것이 더 효율적이다.

# %%
num = 10
statement = '유혁준 바보'

# %% [markdown]
# 위와 같은 코드를 실행하면 컴퓨터는 **10이라는 값을 num이라는 변수에 저장한다**라고 한다.
#
# ![Variable2](img/variable.png)
#
# 메모리에 공간을 지정하여 그 공간의 이름을 num이라고 선언하고 10이라는 값을 그 공간에 저장하는 것.
#
# ### 변수의 이름 지정
#
# 변수 이름은 **꼭 의미가 있어야 한다.**
# 항상 '시간이 지난 뒤에 내 코드를 봤을 때 변수의 의미를 다 기억할 수 있는가', 혹은 '다른 사람이 봤을 때 가독성이 좋은가?'를 생각해야 한다.
#
# 그러면 변수의 이름이 길어질 것 같은데, 그럼 예를 들어 학생의 이름은 studentname으로 써야하는가? 띄어쓰기를 어떻게 표현하지?

# %%
camelCase    = '맨 앞글자 소문자, 띄어쓰기 후 첫 글자 대문자'
pothole_case = '띄어쓰기를 언더바로 표현'
PascalCase   = '맨 앞글자 대문자, 띄어쓰기 후 첫 글자 대문자'

# %% [markdown]
# 띄어쓰기를 표현하며 변수 이름을 지정하기 위한 방법으로 위의 세가지가 있으며, 무엇을 쓰든 상관은 없으나, 코드 처음부터 끝까지 하나의 방법만을 쓰는 것이 국룰.
#
# ### 변수에 저장하는 값의 종류
#
# 1. 정수형 숫자
# 2. 실수형 숫자
# 3. 문자열
# 4. Boolean : True, False을 표현하는 자료형.
# 5. List : 여러 자료형의 묶음
# 6. Dictionary : Key와 Value가 있는 묶음
# 7. Tuple : 생성 이후 수정이 불가능한 묶음
# 8. Set : 집합을 표현한 자료형
#
# 이 중에서, 묶음들은 앞으로 프로그래밍에 아주 많이 사용할 예정이다. 또한, 각 자료형을 다룰 때에 사용되는 모든 메소드를 외울 필요는 없지만, 추가, 삭제, 접근하는 방법 정도는 외우고 있어야 한다.
#
# #### List와 Dictionary의 차이
#
# Dictionary는 앞으로 굉장히 많이 사용하게 될 자료형. 어떻게 보면 어떤 값을 쉽게 저장할 수 있다는 것에서 List와 같은 성격을 가지고 있다.
# 하지만, 내부의 값을 호출할 때를 생각해보면, 저장하는 데이터의 성격은 매우 다르다.

# %%
student_info_with_list = ['Kang Hyung Goo', 29, 'korea Univ', 'Computer']
student_info_with_dict = {'Name' : 'Kang Hyung Goo', 'Age' : 29, 'School' : 'Korea Univ', 'Major' : 'Computer'}

print(student_info_with_list[3])
print(student_info_with_dict['School'])
# Out:
# Computer
# Computer

# %% [markdown]
# List의 3번째가 어떤 데이터인지 호출문을 보고는 알 수가 없다. 반면에 Dictionary는 School의 값을 호출함을 확실하게 알 수 있다.
# 이렇듯, **데이터의 순서가 중요한 경우 List**를 사용하고, **데이터의 특정 속성 값이 필요할 경우 Dictionary**를 사용한다.
#
# ### 연산자
#
# #### 연산자의 종류
#
# * 대입 연산자 : =
# * 산술 연산자 : + - * / // %
# * 비교 연산자 : < > = <= >= == !=
# * 논리 연산자 : ||, or, &&, and
#
# #### 나눗셈의 종류
#
# 나눗셈의 경우, 우리가 흔히 수학에서 사용하는 나눗셈 연산을 뜻하는 '/'와 함께, '//'(몫), '%'(나머지)의 연산이 있다.

# %%
num1 = 7
num2 = 3

share = 7 // 3
rest = 7 % 3

print(num1, '/', num2, '=', share, '...', rest)
# Out:
# 7 / 3 = 2 ... 1

# %% [markdown]
# #### 나눗셈의 활용
#
# 1. A % B의 값이 0이라는 뜻은, A가 B로 나누어 떨어진다는 뜻이며 B가 A의 약수라는 뜻이다.
# 2. A % 2의 경우, 값이 0일 경우 짝수, 1일 경우 홀수라고 판단할 수 있다.
# 3. A // 10의 결과값은, A를 10개를 묶음으로 했을 때의 묶음 수라고 생각할 수 있다.

# %%
number = int(input("input number : "))

print('\n나눗셈의 활용 #1')
# number = 28
for num in range(2, number): # num
    if number % num == 0:
        # number가 num로 나누어 떨어진다.
        share = number // num
        print('{0} * {1} = {2}'.format(num, share, number))
        
print('\n나눗셈의 활용 #2')
if number % 2 == 0:
    # number가 2로 나누어 떨어진다. 즉, 짝수이다.
    print(number, 'is even number')
else:
    # number 2로 나누어 떨어지지 않는다. 즉, 홀수이다.
    print(number, 'is odd number')
    
print('\n나눗셈의 활용 #3')
share = number // 10

for cnt in range(share):
    print(cnt)
# Out:
# input number : 28
#
# 나눗셈의 활용 #1
# 2 * 14 = 28
# 4 * 7 = 28
# 7 * 4 = 28
# 14 * 2 = 28
#
# 나눗셈의 활용 #2
# 28 is even number
#
# 나눗셈의 활용 #3
# 0
# 1

# %% [markdown]
# # 2. 조건문
#
# ## 조건문의 사용 의의
#
# ![flowchart](img/if.png)
#
# 컴퓨터가 항상 같은 동작을 하는 것이 아닌, **특별한 조건에서는 다른 동작을** 할 수 있도록 행동의 분기점을 만드는 것.

# %%
do_my_homework = True # False는 0, True는 0을 제외한 모든 값

if do_my_homework is True: # if do_my_homework: 도 가능
    print('오늘을 불태운다.')
else:
    print('안녕히 주무세요.')
# Out:
# 오늘을 불태운다.

# %% [markdown]
# 또한, if-elif-else를 어떻게 활용하느냐에 따라 다양한 Flowchart를 만들 수 있다.
#
# 이해를 돕기 위해, 학생들의 학점을 매기는 프로그램을 예시로 들어 보면,

# %%
score = int(input('input score :'))

if score > 90:
    print('You got an A')
elif score > 80:
    print('You got a B')
elif score > 70:
    print('You got a C')
elif score > 60:
    print('You got aD')
else:
    print('Fail')

if score == 100:
    print('Perfect score!')
# Out:
# input score :89
# You got a B

# %% [markdown]
# * if-elif-else문의 경우, 위에서부터
#     + **조건이 참일 경우엔 그 코드를 실행하고 if-elif-else문을 종료**한다.
#     + **조건이 참이 아닐 경우 다음 elif의 조건문 혹은 else문으로 이동**한다.
# * 아래의 if문의 경우, **별개의 if문으로 if-elif-else의 과정에 영향을 받지않는다**

# %% [markdown]
# ## 조건문에 관하여
#
# 연산자 중에서 논리 연산자를 활용하면 if문에서 **한번에 여러 조건을 체크**할 수 있다. 이는 이중 if문을 활용하면 같은 효과가 있는데, 어떤 것을 활용하여야 하는지는 답이 없지만 **가독성이 좋다면 그게 정답**이라고 할 수 있다.

# %%
number = int(input('input number :'))

if number % 2 == 0 and number % 3 == 0:
    share = number // 6
    print('{0} * {1} = {2}'.format(6, share, number))
    
if number % 2 == 0:
    if number % 3 == 0:
        print('{0} * {1} = {2}'.format(6, share, number))
# Out:
# input number :29

# %% [markdown]
# # 3. 반복문

# %% [markdown]
# ## 반복문이란
#
# 반복문은 같은 동작을 반복할 때에 사용하는 것으로, 반복문을 사용함으로써 우리의 코드는 **가독성**이 좋아지고, **코드의 수정이 용이**하다는 장점이 생긴다. 반복문을 사용하지 않은 경우와 사용한 경우의 코드를 비교하여 보자.

# %%
# 반복문을 사용하지 않는 경우
number01 = 0
number01 += 1
number01 += 1
number01 += 1
number01 += 1
number01 += 1
number01 += 1
number01 += 1
number01 += 1
number01 += 1
number01 += 1
print('number01 is', number01)

# 반복문을 사용한 경우
number02 = 0
for _ in range(10):
    number02 += 1
print('number02 is', number02)
# Out:
# number01 is 10
# number02 is 10

# %% [markdown]
# 만약 반복이 1000번이라면, 반복문을 사용하지 않을 때에 복붙된 1000줄의 코드가 있을 테고, 만약에 알고리즘 상 +1이 아니라 +2로 바꿔야한다면 1000줄의 모든 숫자를 바꿔야한다.

# %% [markdown]
# ## for와 while의 차이
#
# 반복문을 표현하는 문법으로는 for문과 while문이 있다. for문을 활용한 코드를 while문으로 바꿀 수 있으며 반대도 가능하다.
# 그렇다면 둘의 차이점은 무엇이고 언제 for문을, 언제 while문을 사용해야 하는가.

# %%
print('for문, while문으로 같은 결과 표현 가능')

print("* for문으로 반복문 구현")
print('=> ', end='')
for idx in range(3):
    print(idx, end=' ')
    
print()
print("* while문으로 반복문 구현")
idx = 0
print('=> ', end='')
while idx < 3:
    print(idx, end=' ')
    idx += 1
# Out:
# for문, while문으로 같은 결과 표현 가능
# * for문으로 반복문 구현
# => 0 1 2
# * while문으로 반복문 구현
# => 0 1 2

# %% [markdown]
# for문은 보통 **반복 횟수가 정해져 있는 경우**에 사용하며, while문은 반복 횟수가 정해져 있는 것이 아니지만 **종료 조건이 명확한 경우**에 사용한다.

# %%
number = 1
while number % 6 != 0:
    number = int(input('input number :'))
    print(number)
# Out:
# input number :10
# 10
# input number :9
# 9
# input number :6
# 6

# %% [markdown]
# ## 반복문과 조건문
#
# 반복문 내부에 조건문과 continue 혹은 break문을 사용한다면 더 다양한 문제를 해결할 수 있다.
#
# * continue : 아래의 코드를 무시하고 바로 다음 반복문 실행
# * break : 모든 조건을 무시하고 반복문 종료
#
# 이해를 위해 예시 문제에 적용해보자. 문제는 다음과 같다.
#
# 1. 숫자를 5번 입력받고 입력 받은 숫자들의 합을 출력한다.
# 2. 음수는 무시하고, 입력하는 숫자가 0 ~ 100에 포함되지 않을 경우 반복문을 종료한다.

# %%
sum = 0
for _ in range(5):
    number = int(input("input number :"))
    if number < 0:
        continue
    if number > 100:
        break
    sum += number
    
print("\nTotal :", sum)
# Out:
# input number :10
# input number :20
# input number :-1000000000
# input number :200
#
# Total : 30

# %% [markdown]
# # 4. 함수
#
# ## 함수란
#
# **여러 줄의 코드를 한 줄로 치환**시켜 사용하는 것이다. 파이썬에 기본으로 내장 되어있는 수많은 함수들 덕분에 우리는 모든 것을 직접 코딩할 필요없이, 함수를 가져다가 사용하여 알고리즘을 구성할 수 있다.
#
# 내장 함수 외에 자신이 자주 사용하는 연산을 직접 사용자 정의 함수로 만들어서 사용할 수 있다.

# %%
# 정의부
def avg_grade(score_list): # arguments, 함수로 넘겨주는 값. score_list라는 변수를 생성하여 넘겨받은 값을 저장.
    # 함수의 내부를 설명하는 주석을 이 부분에 추가하는 것이 국룰
    # purpose, arguments, returns가 어떤 것인지 함수 내부를 보지 않고 알 수 있도록 한다.
    """
    Purpose
    -------
    학점 리스트를 받아서 평균 학점을 계산하는 함수

    Arguments
    -------
    - score_list : 각 수업의 학점을 float 형태로 저장한 리스트

    Returns
    -------
    - avg : 평균 학점
    """
    sum = 0
    for score in score_list:
        sum += score
    avg = sum / len(score_list)
    return avg # 함수를 호출부를 대신할 값

A_student = [4.3, 4.0, 3.0, 3.3, 4.3, 3.0]
B_student = [2.3, 3.0, 3.0, 1.3, 0.0, 2.0]
C_student = [4.3, 4.0, 4.0, 4.3, 4.3, 4.3]

print( avg_grade(A_student) ) # 호출부
print( avg_grade(B_student) )
print( avg_grade(C_student) )
# Out:
# 3.6500000000000004
# 1.9333333333333336
# 4.2

# %% [markdown]
# 정해진 형식을 따라 작성하면, IDE에서 함수를 호출할 때 힌트를 준다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 함수의 장점
#
# ### 가독성이 좋아진다
#
# 함수의 이름만으로 코드를 짐작할 수 있다면, Main 부분의 코드는 파이썬 코드가 아닌 영어처럼 보일 수 있다. 이는 전체적인 코드의 흐름과 하고자 하는 바를 쉽게 이해할 수 있으므로 가독성이 좋아진다고 할 수 있다.

# %%
scores = input_score()
avg_score = get_avg_score(scores)
analogy(avg_score)

# %% [markdown]
# ### 코드의 재사용성
#
# 직접 모든 코드를 매번 사용하는 것이 아니라, 코드를 함수로 만들어 재사용함으로 개발 속도를 높힐 수 있다.

# %%
D_student = [4.3, 4.3, 4.3, 4.3, 4.3, 4.3]

print(avg_grade(D_student))
# Out:
# 4.3

# %% [markdown]
# ### Refactoring의 이점
#
# 반복문과 마찬가지로, 수정할 부분이 있다면 그 코드가 쓰인 모든 곳을 수정할 필요없이 함수 내부만 수정하면 문제를 해결할 수 있다.
#
# ### Divide and Conquer
#
# **큰 문제를 작은 문제로 분할하여 해결**하는 방법. 하나의 함수가 하나의 역할을 잘 수행한다면, 그 역할들이 모여 전체의 문제를 해결할 수 있게 되는 것이다. 오류가 발생하였을 때 어디가 문제인지 정확하게 정의할 수 있다.
#
# ![DivideAndConqeur](img/conquer.png)

# %% [markdown]
# ## Well-Made 사용자 정의 함수
#
# 잘 만들어진 사용자 정의 함수란 무엇일까? 다음과 같은 사용자 정의 함수가 조금 더 좋은 코드가 될 수 있도록 바꾸어본다면,

# %%
def message(t, isPrivate):
    if isPrivate:
        print("This is private message. Be careful!!")
        with open("./private.txt", mode='w', encoding='utf-8') as f:
            f.write(t)
    else:
        print("This is public message. Don't care about it.")
        with open("./public.txt", mode='w', encoding='utf-8') as f:
            f.write(t)

# %% [markdown]
# ### 1. 어떤 역할을 하는지 직관적으로 알 수 있는 동사를 쓰자
#
# 변수의 이름을 지을 때와 마찬가지로 함수 또한 **이름에서 부터 어떤 기능을 하는 함수인지 알 수 있도록** 해야한다.

# %%
def sendMessage(t, isPrivate):
    if isPrivate:
        print("This is private message. Be careful!!")
        with open("./private.txt", mode='w', encoding='utf-8') as f:
            f.write(text)
    else:
        print("This is public message. Don't care about it.")
        with open("./public.txt", mode='w', encoding='utf-8') as f:
            f.write(text)

# %% [markdown]
# ### 2. 하나의 함수는 하나의 기능만 하도록 하자
#
# 하나의 함수가 두 가지의 기능을 한다면, Divide가 제대로 되지 않은 상태이다. **하나의 함수는 무조건 하나의 기능**을 가져야 하는 것이 국룰이며, 그렇게 하지 않으면 디버깅을 할 때에 지옥을 보게 될 지도 모른다.
#
# 보통 argument에 boolean을 사용하는 경우, 두가지의 기능을 하는 것일 가능성이 높다. 만약에 argument가 boolean이라면 한번 더 생각해 보아야 한다.

# %%
def sendPrivateMessage(t):
    print("This is private message. Be careful!!")
    with open("./private.txt", mode='w', encoding='utf-8') as f:
        f.write(text)
    
def sendPublicMessage(t):
    print("This is public message. Don't care about it.")
    with open("./public.txt", mode='w', encoding='utf-8') as f:
        f.write(text)

# %% [markdown]
# ### 3. 함수의 argument를 축약어로 하지 말자
#
# 축약어를 사용하게 될 경우, 함수의 내부를 보지 않으면 어떤 argument인지 모르게 된다. 두고두고 사용함에 있어 이해가 확실하게 되기 위해서 argument의 의미를 정확하게 알 수 있게 하기 위해 축약어를 사용하지 않는 것이 바람직하다.

# %%
def sendPrivateMessage(text):
    print("This is private message. Be careful!!")
    with open("./private.txt", mode='w', encoding='utf-8') as f:
        f.write(text)
    
def sendPublicMessage(text):
    print("This is public message. Don't care about it.")
    with open("./public.txt", mode='w', encoding='utf-8') as f:
        f.write(text)
# Out:
# This is private message. Be careful!!
